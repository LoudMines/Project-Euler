# %% [markdown]
# # Project Euler dashboard
# This notebook can be used to generate new problem files, and for getting an overview of all problems and their solve times.

# %%
import Util.Dashboard as Dashboard

display(Dashboard.problem_creator())
# Out:
# Box(children=(VBox(children=(HBox(children=(HTML(value="<span style='font-size:17px; '>Create a file for the n…

# %%
df = Dashboard.problem_table()
print(f"Total solve time: {sum(df["Time (ms)"]): .2f} ms for {len(df.index)} solved problems.")
df
# Out:
# 100%|██████████| 1/1 [00:02<00:00,  2.06s/it]
# Total solve time:  40.06 ms for 29 solved problems.
#                                  Title  \
# 0                         Problem Zero
# 1                  Multiples of 3 or 5
# 2               Even Fibonacci Numbers
# 3                 Largest Prime Factor
# 4           Largest Palindrome Product
# 5                    Smallest Multiple
# 6                Sum Square Difference
# 7                       10 001st Prime
# 8          Largest Product in a Series
# 9          Special Pythagorean Triplet
# 10                 Summation of Primes
# 11           Largest Product in a Grid
# 12  Highly Divisible Triangular Number
# 13                           Large Sum
# 14            Longest Collatz Sequence
# 15                       Lattice Paths
# 16                     Power Digit Sum
# 17                Number Letter Counts
# 18                  Maximum Path Sum I
# 19                    Counting Sundays
# 20                 Factorial Digit Sum
# 21                    Amicable Numbers
# 22                        Names Scores
# 23                   Non-Abundant Sums
# 24          Lexicographic Permutations
# 25       $1000$-digit Fibonacci Number
# 26                   Reciprocal Cycles
# 27                    Quadratic Primes
# 28             Number Spiral Diagonals
#
#                                           Description  Time (ms)  \
# 0   A number is a perfect square, or a square numb...   0.000092
# 1   <p>If we list all the natural numbers below $1...   0.000182
# 2   <p>Each new term in the Fibonacci sequence is ...   0.000169
# 3   <p>The prime factors of $13195$ are $5, 7, 13$...   0.011380
# 4   <p>A palindromic number reads the same both wa...   1.075841
# 5   <p>$2520$ is the smallest number that can be d...   0.007074
# 6   <p>The sum of the squares of the first ten nat...   0.000075
# 7   <p>By listing the first six prime numbers: $2,...   0.720925
# 8   <p>The four adjacent digits in the $1000$-digi...   0.066155
# 9   <p>A Pythagorean triplet is a set of three nat...   0.000148
# 10  <p>The sum of the primes below $10$ is $2 + 3 ...   4.333543
# 11  <p>In the $20 \times 20$ grid below, four numb...   0.041258
# 12  <p>The sequence of triangle numbers is generat...   8.164517
# 13  <p>Work out the first ten digits of the sum of...   0.096392
# 14  <p>The following iterative sequence is defined...  10.506183
# 15  <p>Starting in the top left corner of a $2 \ti...   0.000736
# 16  <p>$2^{15} = 32768$ and the sum of its digits ...   0.254901
# 17  <p>If the numbers $1$ to $5$ are written out i...   0.025280
# 18  <p>By starting at the top of the triangle belo...   0.015952
# 19  <p>You are given the following information, bu...   0.003909
# 20  <p>$n!$ means $n \times (n - 1) \times \cdots ...   0.019299
# 21  <p>Let $d(n)$ be defined as the sum of proper ...   2.269794
# 22  <p>Using <a href="resources/documents/0022_nam...   1.982750
# 23  <p>A perfect number is a number for which the ...   6.252819
# 24  <p>A permutation is an ordered arrangement of ...   0.006624
# 25  <p>The Fibonacci sequence is defined by the re...   0.000232
# 26  <p>A unit fraction contains $1$ in the numerat...   0.399171
# 27  <p>Euler discovered the remarkable quadratic f...   3.807654
# 28  <p>Starting with the number $1$ and moving to ...   0.000073
#
#                                  Solver  First                 Last tested
# 0                         odd_n_squares  False  2026-08-19T17:12:15.790264
# 1                             multiples  False  2026-08-19T17:12:17.729655
# 2                rounding_nth_fibonacci  False  2026-08-19T17:12:19.849516
# 3                   brute_force_no_even  False  2026-08-19T17:12:25.386735
# 4   better_palindrome_check_brute_force  False  2026-08-19T17:12:32.707821
# 5                   prime_factorisation  False  2026-08-19T17:12:35.953995
# 6                            best_solve  False  2026-08-19T17:12:37.546651
# 7                      calculated_limit  False  2026-08-19T17:12:49.745580
# 8              zero_split_running_total  False  2026-08-19T17:12:56.778264
# 9                       euclids_formula  False  2026-08-19T22:16:54.514758
# 10              eratosthenes_wheel_four  False  2026-08-19T17:13:12.364892
# 11                        per_direction  False  2026-08-19T17:13:17.792362
# 12            lower_bound_factorisation  False  2026-08-19T17:13:20.928422
# 13                           best_solve  False  2026-08-19T17:13:25.286793
# 14                      array_recursion  False  2026-08-19T17:13:59.016125
# 15             mathematical_calculation   True  2026-08-19T17:14:00.130820
# 16               optimised_number_array  False  2026-08-19T17:14:02.785722
# 17                   separated_hundreds  False  2026-08-19T17:14:05.096055
# 18                            bottom_up  False  2026-08-19T17:14:09.889068
# 19                          brute_force   True  2026-08-19T17:14:11.315909
# 20                  no_multiples_of_ten  False  2026-08-19T17:14:15.929506
# 21            boolean_array_running_sum  False  2026-08-19T17:14:31.281730
# 22                          brute_force   True  2026-08-19T17:14:34.317030
# 23           faster_creation_bool_array  False  2026-08-19T17:14:47.250328
# 24                    index_calculation   True  2026-08-19T17:14:49.344951
# 25                        nth_Fibonacci  False  2026-08-19T17:14:52.600259
# 26        long_division_decimal_options  False  2026-08-25T21:21:53.434138
# 27                        reduced_scope  False  2026-08-27T19:32:52.798682
# 28                  squares_calculation   True  2026-08-27T20:34:03.806325
