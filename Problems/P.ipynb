# %%
from Util import update_class, Problem, solution


class P(Problem):
    number = 999
    title = ""
    description = (
        "\n" +
        ""
    )

# %%
p = P()
p.describe()
# Out:
# ## Problem 999:

# %%
@update_class()
class P(Problem):
    @solution(first=True)
    def brute_force(self):
        return 1, ""

# %%
p.test_all()
# Out:
# (1, '')

# %%
@update_class()
class P(Problem):
    @solution(best=True)
    def best_solve(self):
        return 1, ""

# %%
p.test_all()
# Out:
# First result: 1 found in  0.000005 seconds.
# Best result: 1 found in  0.000004 seconds.
