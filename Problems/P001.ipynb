# %%
from Util import Problem, solution


class P001(Problem):
    number = 1
    title = "Multiples of 3 or 5"
    description = (
        "<p>If we list all the natural numbers below $10$ that are multiples of $3$ or $5$, we get " +
        "$3, 5, 6$ and $9$. The sum of these multiples is $23$. </p>" +
        "<p>Find the sum of all the multiples of $3$ or $5$ below $1000$.</p>"
    )

# %%
p = P001()
p.describe()
# Out:
# ## Problem 1: Multiples of 3 or 5
#
# <p>If we list all the natural numbers below $10$ that are multiples of $3$ or $5$, we get $3, 5, 6$ and $9$. The sum of these multiples is $23$. </p><p>Find the sum of all the multiples of $3$ or $5$ below $1000$.</p>

# %%
@solution(P001, first=True, make_fast=True)
def simple():
    sum_of_multiples = 0
    for i in range(1, 1000):
        if i % 3 == 0 or i % 5 == 0:
            sum_of_multiples += i
    return sum_of_multiples

# %%
p.test_all()
# Out:
# 233168 found in 0.000550 ms by simple (first)

# %%
@solution(P001, best=True, make_fast=True)
def multiples():
    sum_of_multiples = 0
    i = 3
    while i < 1000:
        sum_of_multiples += i
        i += 3
    j = 5
    while j < 1000:
        if j % 3 != 0:
            sum_of_multiples += j
        j += 5
    return sum_of_multiples

# %%
p.test_all()
# Out:
# 233168 found in 0.000165 ms by multiples (best)
# 233168 found in 0.000538 ms by simple (first)
