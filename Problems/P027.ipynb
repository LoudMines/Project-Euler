# %%
from Util.Problems import Problem, solution

import Util.math_functions as mathf


class P027(Problem):
    number = 27
    title = "Quadratic Primes"
    description = """<p>Euler discovered the remarkable quadratic formula:</p><p class="center">$n^2 + n + 41$</p><p>It turns out that the formula will produce $40$ primes for the consecutive integer values $0 \\le n \\le 39$. However, when $n = 40, 40^2 + 40 + 41 = 40(40 + 1) + 41$ is divisible by $41$, and certainly when $n = 41, 41^2 + 41 + 41$ is clearly divisible by $41$.</p><p>The incredible formula $n^2 - 79n + 1601$ was discovered, which produces $80$ primes for the consecutive values $0 \\le n \\le 79$. The product of the coefficients, $-79$ and $1601$, is $-126479$.</p><p>Considering quadratics of the form:</p><blockquote>
$n^2 + an + b$, where $|a| < 1000$ and $|b| \\le 1000$<br/><br/><div>where $|n|$ is the modulus/absolute value of $n$<br/>e.g. $|11| = 11$ and $|-4| = 4$</div>
</blockquote><p>Find the product of the coefficients, $a$ and $b$, for the quadratic expression that produces the maximum number of primes for consecutive values of $n$, starting with $n = 0$.</p>"""
    a_limit = 999
    b_limit = 1000

# %%
p = P027()
p.describe()
# Out:
# ## Problem 27: Quadratic Primes
#
# <p>Euler discovered the remarkable quadratic formula:</p><p class="center">$n^2 + n + 41$</p><p>It turns out that the formula will produce $40$ primes for the consecutive integer values $0 \le n \le 39$. However, when $n = 40, 40^2 + 40 + 41 = 40(40 + 1) + 41$ is divisible by $41$, and certainly when $n = 41, 41^2 + 41 + 41$ is clearly divisible by $41$.</p><p>The incredible formula $n^2 - 79n + 1601$ was discovered, which produces $80$ primes for the consecutive values $0 \le n \le 79$. The product of the coefficients, $-79$ and $1601$, is $-126479$.</p><p>Considering quadratics of the form:</p><blockquote>
# $n^2 + an + b$, where $|a| < 1000$ and $|b| \le 1000$<br/><br/><div>where $|n|$ is the modulus/absolute value of $n$<br/>e.g. $|11| = 11$ and $|-4| = 4$</div>
# </blockquote><p>Find the product of the coefficients, $a$ and $b$, for the quadratic expression that produces the maximum number of primes for consecutive values of $n$, starting with $n = 0$.</p>

# %% [markdown]
# ### Solution notes
# First the most simple brute-force solution: looping through all a and b, keeping track of the number of n for which they are prime, returning the result which stayed prime the longest.

# %%
@solution(P027, first=True, make_fast=True, warmup_args=(P027.a_limit, P027.b_limit))
def brute_force(a_limit, b_limit):
    biggest_n = 0
    result = 0
    for a in range(-a_limit, a_limit + 1):
        for b in range(-b_limit, b_limit + 1):
            n = 0
            while mathf.is_prime(n ** 2 + a * n + b):
                n += 1
            if n > biggest_n:
                biggest_n = n
                result = a * b
    return result

# %%
p.test_once("brute_force")
# Out:
# -59231 found after a separate test in 19.284300 ms by brute_force (first)

# %% [markdown]
# Because we start at $n=0$, $b$ always has to be prime. Otherwise, $0^2 + a \times 0 + b = b$ is already not prime.
#
# Looking at the next cases, we can determine what $a$ should be (where $p_1, p_2$ etc. are primes):
#
# $n=1: 1^2 + a + b = p_1 \\
# a = p_1 - b - 1 \\
# \\
# n=2: 2^2 + 2a + b = p_2\\
# 2a = p_2 - b - 4\\
# a = \frac{p_2}{2}-\frac{b}{2} - 2$
#
# We can use these two equations, to write $b$ in terms of the first two primes:
#
# $p_1 - b - 1 = \frac{p_2}{2}-\frac{b}{2} - 2 \\
# p_1 - b + 1 - \frac{p_2}{2} = -\frac{b}{2} \\
# \frac{b}{2} = p_1 - \frac{p_2}{2} + 1 \\
# b = 2p_1 - p_2 + 2$
#
# If we fill this in in the equation for $a$ derived from $n=20$, we get:
#
# $a = \frac{p_2}{2}-\frac{2p_1 - p_2 + 2}{2} - 2\\
# a = \frac{p_2}{2}-p_1+\frac{p_2}{2} - 1 - 2\\
# a = p_2-p_1- 3\\
# $

# %%
@solution(P027, best=True, make_fast=True)
def best_solve():
    return brute_force()
# Out:
# ---------------------------------------------------------------------------
# TypingError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 @solution(P027, best=True, make_fast=True)
#       2 def best_solve():
#       3     return brute_force()
#
# File ~\Documents\Project Euler\Util\Problems.py:31, in solution.<locals>.decorator(func)
#      27     target = njit()(func) if make_fast else func
#      29 # Run jitted functions once to compile them.
#      30 # if make_fast:
# ---> 31 target(*warmup_args)
#      33 def method(_):
#      34     result = target(*warmup_args)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\numba\core\dispatcher.py:422, in _DispatcherBase._compile_for_args(self, *args, **kws)
#     418         msg = (f"{str(e).rstrip()} \n\nThis error may have been caused "
#     419                f"by the following argument(s):\n{args_str}\n")
#     420         e.patch_message(msg)
# --> 422     error_rewrite(e, 'typing')
#     423 except errors.UnsupportedError as e:
#     424     # Something unsupported is present in the user code, add help info
#     425     error_rewrite(e, 'unsupported_error')
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\numba\core\dispatcher.py:363, in _DispatcherBase._compile_for_args.<locals>.error_rewrite(e, issue_type)
#     361     raise e
#     362 else:
# --> 363     raise e.with_traceback(None)
#
# TypingError: Failed in nopython mode pipeline (step: nopython frontend)
# Cannot bind 'args=() kws={}' to signature '(a_limit, b_limit)' due to "TypeError: missing a required argument: 'a_limit'".
# During: resolving callee type: type(CPUDispatcher(<function brute_force at 0x0000016A17F90040>))
# During: typing of call at C:\Users\luitm\AppData\Local\Temp\ipykernel_2196\740658021.py (3)
#
# File "..\..\..\AppData\Local\Temp\ipykernel_2196\740658021.py", line 3:
# <source missing, REPL/exec in use?>
#
# During: Pass nopython_type_inference

# %%
p.test_all()
